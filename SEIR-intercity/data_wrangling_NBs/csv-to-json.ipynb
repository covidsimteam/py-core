# %%
import pandas as pd
import geopandas as gpd

# %%
arr_df = pd.read_csv('data_output/synthetic_arrivals.csv')
qua_df = pd.read_csv('data_output/synthetic_quarantined.csv')
iso_df = pd.read_csv('data_output/synthetic_isolated.csv')
inf_df = pd.read_csv('data_output/synthetic_infected.csv')
rec_df = pd.read_csv('data_output/synthetic_recovered.csv')
dea_df = pd.read_csv('data_output/synthetic_death.csv')

# %% [markdown]
# ### Let's read a shapefile to figure out which provinces each district belong to

# %%
dists = gpd.read_file('nepal-map-governance/NEPAL_DISTRICTS_WGS.shp')
dists.head(20)
# Out:
#      DDGN  FIRST_DCOD  FIRST_DIST  FIRST_GN_C  FIRST_STAT     SHAPE_LENG  \
# 0   72001          72  KANCHANPUR         1.0           7   61398.506242
# 1   71001          71     KAILALI         1.0           7   53523.793758
# 2   75001          75    DARCHULA         1.0           7  136857.950678
# 3   70001          70        DOTI         1.0           7   70563.556809
# 4   73001          73  DADELDHURA         1.0           7   75657.458052
# 5   68001          68     BAJHANG         1.0           7   56003.179479
# 6   67099          67      BAJURA        99.0           7   16729.812963
# 7   74001          74     BAITADI         1.0           7   72884.037404
# 8   69001          69      ACHHAM         1.0           7   38661.135483
# 9   54001          54     RUKUM_W         1.0           6  145223.675668
# 10  55001          55      SALYAN         1.0           6   65971.192917
# 11  65001          65        MUGU         1.0           6  136862.053618
# 12  64001          64     KALIKOT         1.0           6   43298.973308
# 13  63001          63       JUMLA         1.0           6   44227.981521
# 14  61001          61    JAJARKOT         1.0           6  114062.341255
# 15  66001          66       HUMLA         1.0           6   61530.768410
# 16  62001          62       DOLPA         1.0           6  255200.906515
# 17  60001          60     DAILEKH         1.0           6   78796.209912
# 18  59001          59     SURKHET         1.0           6  127022.000240
# 19  52001          52     PYUTHAN         1.0           5   80283.256422
#
#       SHAPE_AREA  Area  Centroid_X  Centroid_Y  Geom  \
# 0   1.599160e+08   0.0   80.321796   28.861824  None
# 1   7.725899e+07   0.0   80.879225   28.741642  None
# 2   6.139468e+08   0.0   80.791893   29.891950  None
# 3   1.284703e+08   0.0   80.894570   29.169642  None
# 4   1.489037e+08   0.0   80.489069   29.223122  None
# 5   8.614779e+07   0.0   81.178718   29.708245  None
# 6   7.561569e+06   0.0   81.563163   29.561322  None
# 7   1.351532e+08   0.0   80.571517   29.507541  None
# 8   5.826264e+07   0.0   81.297112   29.112568  None
# 9   5.603414e+08   0.0   82.460452   28.738838  None
# 10  1.631361e+08   0.0   82.138748   28.396499  None
# 11  4.806750e+08   0.0   82.370593   29.618075  None
# 12  9.731523e+07   0.0   81.752033   29.195115  None
# 13  1.020334e+08   0.0   82.217267   29.271714  None
# 14  5.775006e+08   0.0   82.167871   28.865380  None
# 15  1.506150e+08   0.0   81.879866   30.032322  None
# 16  1.965044e+09   0.0   83.052170   29.170656  None
# 17  1.679965e+08   0.0   81.678876   28.881389  None
# 18  4.550917e+08   0.0   81.586408   28.641183  None
# 19  1.567367e+08   0.0   82.865025   28.115454  None
#
#                                              geometry
# 0   POLYGON ((80.18686 29.12730, 80.18682 29.12667...
# 1   POLYGON ((80.56604 29.06221, 80.56632 29.06219...
# 2   POLYGON ((80.98957 30.24626, 80.99008 30.24612...
# 3   POLYGON ((80.92900 29.42084, 80.92974 29.42047...
# 4   POLYGON ((80.68917 29.42236, 80.68937 29.42229...
# 5   POLYGON ((81.09006 30.05419, 81.09033 30.05418...
# 6   POLYGON ((81.69810 29.94108, 81.69822 29.94061...
# 7   POLYGON ((80.75845 29.70453, 80.75864 29.70430...
# 8   POLYGON ((81.17123 29.38651, 81.17158 29.38636...
# 9   POLYGON ((82.58349 28.98759, 82.58429 28.98714...
# 10  POLYGON ((82.05415 28.63667, 82.05406 28.63571...
# 11  POLYGON ((82.56464 29.94622, 82.56443 29.94592...
# 12  POLYGON ((81.84827 29.46065, 81.84961 29.46045...
# 13  POLYGON ((82.32871 29.50787, 82.32877 29.50759...
# 14  POLYGON ((82.28401 29.12218, 82.28435 29.12161...
# 15  POLYGON ((81.62634 30.44588, 81.62675 30.44587...
# 16  POLYGON ((82.91659 29.70618, 82.91696 29.70617...
# 17  POLYGON ((81.57923 29.13596, 81.58008 29.13555...
# 18  POLYGON ((81.06085 28.97172, 81.06190 28.97129...
# 19  POLYGON ((82.94874 28.36205, 82.94920 28.36179...

# %%
province_mapper = lambda x: \
    'Province1' if x == 1 else \
    'Province2' if x == 2 else \
    'Bagmati' if x == 3 else \
    'Gandaki' if x == 4 else \
    'Province5' if x == 5 else  \
    'Karnali' if x == 6 else 'Sudurpaschim'

dists['PROVINCE'] = dists.FIRST_STAT.map(province_mapper)

# %%
# We will need to convert _E's and _W's 
# to East and West for four districts
# to match it with rest of our data

district_e_w_mapper = lambda x: \
    'Rukum east' if x == 'RUKUM_E' else \
    'Rukum west' if x == 'RUKUM_W' else \
    'Nawalparasi east' if x == 'NAWALPARASI_E' else \
    'Nawalparasi west' if x == 'NAWALPARASI_W' else x

cleaned_dists = dists['FIRST_DIST'].map(district_e_w_mapper).str.title()
dists['CLEAN_DIST'] = cleaned_dists

dists.head(20)
# Out:
#      DDGN  FIRST_DCOD  FIRST_DIST  FIRST_GN_C  FIRST_STAT     SHAPE_LENG  \
# 0   72001          72  KANCHANPUR         1.0           7   61398.506242
# 1   71001          71     KAILALI         1.0           7   53523.793758
# 2   75001          75    DARCHULA         1.0           7  136857.950678
# 3   70001          70        DOTI         1.0           7   70563.556809
# 4   73001          73  DADELDHURA         1.0           7   75657.458052
# 5   68001          68     BAJHANG         1.0           7   56003.179479
# 6   67099          67      BAJURA        99.0           7   16729.812963
# 7   74001          74     BAITADI         1.0           7   72884.037404
# 8   69001          69      ACHHAM         1.0           7   38661.135483
# 9   54001          54     RUKUM_W         1.0           6  145223.675668
# 10  55001          55      SALYAN         1.0           6   65971.192917
# 11  65001          65        MUGU         1.0           6  136862.053618
# 12  64001          64     KALIKOT         1.0           6   43298.973308
# 13  63001          63       JUMLA         1.0           6   44227.981521
# 14  61001          61    JAJARKOT         1.0           6  114062.341255
# 15  66001          66       HUMLA         1.0           6   61530.768410
# 16  62001          62       DOLPA         1.0           6  255200.906515
# 17  60001          60     DAILEKH         1.0           6   78796.209912
# 18  59001          59     SURKHET         1.0           6  127022.000240
# 19  52001          52     PYUTHAN         1.0           5   80283.256422
#
#       SHAPE_AREA  Area  Centroid_X  Centroid_Y  Geom  \
# 0   1.599160e+08   0.0   80.321796   28.861824  None
# 1   7.725899e+07   0.0   80.879225   28.741642  None
# 2   6.139468e+08   0.0   80.791893   29.891950  None
# 3   1.284703e+08   0.0   80.894570   29.169642  None
# 4   1.489037e+08   0.0   80.489069   29.223122  None
# 5   8.614779e+07   0.0   81.178718   29.708245  None
# 6   7.561569e+06   0.0   81.563163   29.561322  None
# 7   1.351532e+08   0.0   80.571517   29.507541  None
# 8   5.826264e+07   0.0   81.297112   29.112568  None
# 9   5.603414e+08   0.0   82.460452   28.738838  None
# 10  1.631361e+08   0.0   82.138748   28.396499  None
# 11  4.806750e+08   0.0   82.370593   29.618075  None
# 12  9.731523e+07   0.0   81.752033   29.195115  None
# 13  1.020334e+08   0.0   82.217267   29.271714  None
# 14  5.775006e+08   0.0   82.167871   28.865380  None
# 15  1.506150e+08   0.0   81.879866   30.032322  None
# 16  1.965044e+09   0.0   83.052170   29.170656  None
# 17  1.679965e+08   0.0   81.678876   28.881389  None
# 18  4.550917e+08   0.0   81.586408   28.641183  None
# 19  1.567367e+08   0.0   82.865025   28.115454  None
#
#                                              geometry      PROVINCE  \
# 0   POLYGON ((80.18686 29.12730, 80.18682 29.12667...  Sudurpaschim
# 1   POLYGON ((80.56604 29.06221, 80.56632 29.06219...  Sudurpaschim
# 2   POLYGON ((80.98957 30.24626, 80.99008 30.24612...  Sudurpaschim
# 3   POLYGON ((80.92900 29.42084, 80.92974 29.42047...  Sudurpaschim
# 4   POLYGON ((80.68917 29.42236, 80.68937 29.42229...  Sudurpaschim
# 5   POLYGON ((81.09006 30.05419, 81.09033 30.05418...  Sudurpaschim
# 6   POLYGON ((81.69810 29.94108, 81.69822 29.94061...  Sudurpaschim
# 7   POLYGON ((80.75845 29.70453, 80.75864 29.70430...  Sudurpaschim
# 8   POLYGON ((81.17123 29.38651, 81.17158 29.38636...  Sudurpaschim
# 9   POLYGON ((82.58349 28.98759, 82.58429 28.98714...       Karnali
# 10  POLYGON ((82.05415 28.63667, 82.05406 28.63571...       Karnali
# 11  POLYGON ((82.56464 29.94622, 82.56443 29.94592...       Karnali
# 12  POLYGON ((81.84827 29.46065, 81.84961 29.46045...       Karnali
# 13  POLYGON ((82.32871 29.50787, 82.32877 29.50759...       Karnali
# 14  POLYGON ((82.28401 29.12218, 82.28435 29.12161...       Karnali
# 15  POLYGON ((81.62634 30.44588, 81.62675 30.44587...       Karnali
# 16  POLYGON ((82.91659 29.70618, 82.91696 29.70617...       Karnali
# 17  POLYGON ((81.57923 29.13596, 81.58008 29.13555...       Karnali
# 18  POLYGON ((81.06085 28.97172, 81.06190 28.97129...       Karnali
# 19  POLYGON ((82.94874 28.36205, 82.94920 28.36179...     Province5
#
#     CLEAN_DIST
# 0   Kanchanpur
# 1      Kailali
# 2     Darchula
# 3         Doti
# 4   Dadeldhura
# 5      Bajhang
# 6       Bajura
# 7      Baitadi
# 8       Achham
# 9   Rukum West
# 10      Salyan
# 11        Mugu
# 12     Kalikot
# 13       Jumla
# 14    Jajarkot
# 15       Humla
# 16       Dolpa
# 17     Dailekh
# 18     Surkhet
# 19     Pyuthan

# %%
# Let's check if any of the districts'
# spellings do not match

shp_dists = set(sorted(list(dists.CLEAN_DIST)))
our_dists = set(sorted(list(arr_df.columns[1:])))

shp_dists == our_dists
# Out:
# True

# %% [markdown]
# #### **GOOD!**

# %%
import json

# %%
arr_df
# Out:
#            Date  Panchthar  Ilam  Jhapa  Morang  Sunsari  Terhathum  Bhojpur  \
# 0    2020-03-30          0   3.0   46.0       0        0      309.0        0
# 1    2020-03-31          0   0.0  251.0       0       24      229.0        0
# 2    2020-04-01          0   5.0    0.0       0        0      312.0        0
# 3    2020-04-02          0   0.0    0.0       0       40      300.0        0
# 4    2020-04-03          0   4.0    0.0       0        0      292.0        0
# ..          ...        ...   ...    ...     ...      ...        ...      ...
# 154  2020-08-31          0   0.0    0.0       0       29      156.0        0
# 155  2020-09-01          0   0.0  100.0       0       36      285.0        0
# 156  2020-09-02          0   6.0    0.0       0       10      223.0        0
# 157  2020-09-03          0   6.0    0.0       0        0      302.0        0
# 158  2020-09-04          0   0.0  158.0       0       48       43.0        0
#
#      Sankhuwasabha  Solukhumbu  ...  Jajarkot  Bardiya  Kailali  Achham  \
# 0              2.0       210.0  ...         0    398.0     85.0     2.0
# 1              1.0       119.0  ...         0      0.0     87.0    33.0
# 2              0.0       388.0  ...       290   1260.0     57.0     0.0
# 3              0.0       401.0  ...       316    440.0     41.0     2.0
# 4              0.0      1227.0  ...        23    950.0     79.0     9.0
# ..             ...         ...  ...       ...      ...      ...     ...
# 154            0.0        53.0  ...         2   1573.0    107.0    23.0
# 155            0.0       358.0  ...        77    762.0     26.0     0.0
# 156           21.0         0.0  ...         0   1370.0     40.0     8.0
# 157            0.0         0.0  ...       323    787.0     72.0     9.0
# 158            1.0       598.0  ...       304      0.0     18.0     0.0
#
#      Bajhang  Darchula  Dadeldhura  Nawalparasi East  Nawalparasi West  \
# 0          0       3.0           0              16.0             119.0
# 1          0      36.0         462             265.0              39.0
# 2         25      41.0          95             763.0             221.0
# 3          3      74.0         581             811.0             179.0
# 4          0      61.0          75             337.0              87.0
# ..       ...       ...         ...               ...               ...
# 154        0       0.0          40               0.0               0.0
# 155       19      66.0           0               0.0             369.0
# 156        0     143.0         502             584.0              37.0
# 157        0     122.0          34             247.0               1.0
# 158        0     142.0           0               0.0               7.0
#
#      Rukum West
# 0         600.0
# 1         199.0
# 2          83.0
# 3           0.0
# 4         337.0
# ..          ...
# 154       413.0
# 155         0.0
# 156         0.0
# 157       370.0
# 158       308.0
#
# [159 rows x 78 columns]

# %%
def approximate_and_save_district(dataset, pschema, path):
    _ids = 'province:' + dists.PROVINCE + ':district:' + dists.CLEAN_DIST
    dates = dataset.Date

    for _id in _ids:
        json_str = {
            "_id": _id,
            "_rev": None,
            "pschema": pschema,
            "data": []
        }

        for idx, date in enumerate(dates):
            json_str['data'].append([
                _id, _id.split(':')[1], _id.split(':')[-1],
                dataset[_id.split(':')[-1]][idx].astype('str'),
                None
            ])

        with open(path + _id.split(':')[-1] + '.json', 'w') as outfile:
            json.dump(json_str, outfile)

# %%
approximate_and_save_district(qua_df, "quarantined/v8", "districtwise_jsons/quarantined/")
approximate_and_save_district(arr_df, "arrivals/v8", "districtwise_jsons/arrivals/")
approximate_and_save_district(iso_df, "isolated/v8", "districtwise_jsons/isolated/")
approximate_and_save_district(inf_df, "infected/v8", "districtwise_jsons/infected/")
approximate_and_save_district(rec_df, "recovered/v8", "districtwise_jsons/recovered/")
approximate_and_save_district(dea_df, "dead/v8", "districtwise_jsons/dead/")

# %% [markdown]
# #### **GREAT!**

# %%
wards = gpd.read_file('nepal-map-governance/NEPAL_WARDS_WGS.shp')
wards
# Out:
#       OBJECTID  DCODE      DISTRICT   DAN  DAS      GaPa_NaPa  \
# 0            1     51  ARGHAKHANCHI  None    0   Sandhikharka
# 1            2     51  ARGHAKHANCHI  None    0   Sandhikharka
# 2            3     51  ARGHAKHANCHI  None    0       Malarani
# 3            4     51  ARGHAKHANCHI  None    0     Chhatradev
# 4            5     51  ARGHAKHANCHI  None    0       Malarani
# ...        ...    ...           ...   ...  ...            ...
# 6798      6799     33          BARA  None    0  Jitpur Simara
# 6799      6800     33          BARA  None    0        Kolhabi
# 6800      6801     33          BARA  None    0        Kolhabi
# 6801      6802     33          BARA  None    0  Jitpur Simara
# 6802      6803     33          BARA  None    0  Jitpur Simara
#
#                  Type_GN  GN_CODE  NEW_WARD_N    DDGNWW         CENTER  \
# 0            Nagarpalika      5.0           9  510509.0   Sandhikharka
# 1            Nagarpalika      5.0          10  510510.0   Sandhikharka
# 2             Gaunpalika      3.0           1  510301.0  Khandaha Gufa
# 3             Gaunpalika      2.0           8  510208.0    Chhatragunj
# 4             Gaunpalika      3.0           2  510302.0  Khandaha Gufa
# ...                  ...      ...         ...       ...            ...
# 6798  Upamahanagarpalika      5.0          18  330518.0         Jitpur
# 6799         Nagarpalika      8.0          11  330811.0  Kolhabi Bazar
# 6800         Nagarpalika      8.0           5  330805.0  Kolhabi Bazar
# 6801  Upamahanagarpalika      5.0           9  330509.0         Jitpur
# 6802  Upamahanagarpalika      5.0           8  330508.0         Jitpur
#
#       STATE_CODE   DDGN  Area_SQKM    Shape_Leng    Shape_Area  \
# 0              5  51005  11.173221  18511.444524  1.117322e+07
# 1              5  51005   8.840185  16383.537556  8.840185e+06
# 2              5  51003   5.797200  13644.745047  5.797200e+06
# 3              5  51002  14.180764  28896.050509  1.418076e+07
# 4              5  51003   8.470847  17679.412852  8.470847e+06
# ...          ...    ...        ...           ...           ...
# 6798           2  33005   7.888778  16309.015899  7.888778e+06
# 6799           2  33008   7.203428  19989.499583  7.203428e+06
# 6800           2  33008  20.554515  32475.975107  2.055451e+07
# 6801           2  33005   3.366166  10497.037372  3.366166e+06
# 6802           2  33005   7.800887  17882.351592  7.800887e+06
#
#                                                geometry
# 0     POLYGON ((83.12000 28.02279, 83.11993 28.02282...
# 1     POLYGON ((83.13196 28.01999, 83.13172 28.01987...
# 2     POLYGON ((83.17366 28.02966, 83.17362 28.02976...
# 3     POLYGON ((83.20093 28.07265, 83.20096 28.07263...
# 4     POLYGON ((83.18839 28.06681, 83.18842 28.06664...
# ...                                                 ...
# 6798  POLYGON ((85.06679 27.14009, 85.06679 27.13918...
# 6799  POLYGON ((85.15612 27.07047, 85.15654 27.07044...
# 6800  MULTIPOLYGON (((85.13311 27.08342, 85.13347 27...
# 6801  POLYGON ((84.95056 27.11354, 84.95032 27.11285...
# 6802  POLYGON ((84.95755 27.12321, 84.95909 27.12291...
#
# [6803 rows x 17 columns]

# %%
ktm_wards = wards[wards['DISTRICT'] == 'KATHMANDU']
ktm_wards
# Out:
#       OBJECTID  DCODE   DISTRICT   DAN  DAS            GaPa_NaPa      Type_GN  \
# 3706      3707     27  KATHMANDU  None    0         Gokarneshwor  Nagarpalika
# 3707      3708     27  KATHMANDU  None    0         Gokarneshwor  Nagarpalika
# 3708      3709     27  KATHMANDU  None    0         Gokarneshwor  Nagarpalika
# 3709      3710     27  KATHMANDU  None    0         Gokarneshwor  Nagarpalika
# 3710      3711     27  KATHMANDU  None    0         Gokarneshwor  Nagarpalika
# ...        ...    ...        ...   ...  ...                  ...          ...
# 3839      3840     27  KATHMANDU  None    0  Kageshwori Manahora  Nagarpalika
# 3840      3841     27  KATHMANDU  None    0  Kageshwori Manahora  Nagarpalika
# 3841      3842     27  KATHMANDU  None    0  Kageshwori Manahora  Nagarpalika
# 3842      3843     27  KATHMANDU  None    0  Kageshwori Manahora  Nagarpalika
# 3843      3844     27  KATHMANDU  None    0  Kageshwori Manahora  Nagarpalika
#
#       GN_CODE  NEW_WARD_N    DDGNWW                                  CENTER  \
# 3706      4.0           3  270403.0        Gokarneshwor Municipality Office
# 3707      4.0           4  270404.0        Gokarneshwor Municipality Office
# 3708      4.0           5  270405.0        Gokarneshwor Municipality Office
# 3709      4.0           6  270406.0        Gokarneshwor Municipality Office
# 3710      4.0           8  270408.0        Gokarneshwor Municipality Office
# ...       ...         ...       ...                                     ...
# 3839      5.0           1  270501.0  Kageshwori Manahora Nagarpalika Office
# 3840      5.0           2  270502.0  Kageshwori Manahora Nagarpalika Office
# 3841      5.0           3  270503.0  Kageshwori Manahora Nagarpalika Office
# 3842      5.0           6  270506.0  Kageshwori Manahora Nagarpalika Office
# 3843      5.0           7  270507.0  Kageshwori Manahora Nagarpalika Office
#
#       STATE_CODE   DDGN  Area_SQKM    Shape_Leng    Shape_Area  \
# 3706           3  27004   7.012783  13079.304062  7.012783e+06
# 3707           3  27004   4.691887  14361.326371  4.691887e+06
# 3708           3  27004   1.075972   4769.744766  1.075972e+06
# 3709           3  27004   0.559092   3503.426307  5.590917e+05
# 3710           3  27004   1.309237   5344.986086  1.309237e+06
# ...          ...    ...        ...           ...           ...
# 3839           3  27005  10.764350  17681.728743  1.076435e+07
# 3840           3  27005   1.470396   6235.762132  1.470396e+06
# 3841           3  27005   1.670991   8327.919889  1.670991e+06
# 3842           3  27005   3.021066   8602.488688  3.021066e+06
# 3843           3  27005   1.970700   9830.578605  1.970700e+06
#
#                                                geometry
# 3706  POLYGON ((85.40332 27.77693, 85.40328 27.77686...
# 3707  POLYGON ((85.40531 27.73721, 85.40515 27.73690...
# 3708  POLYGON ((85.37878 27.71702, 85.37845 27.71750...
# 3709  POLYGON ((85.38245 27.72446, 85.38249 27.72432...
# 3710  POLYGON ((85.38586 27.73292, 85.38596 27.73283...
# ...                                                 ...
# 3839  POLYGON ((85.46283 27.77520, 85.46290 27.77512...
# 3840  POLYGON ((85.42474 27.75353, 85.42511 27.75317...
# 3841  POLYGON ((85.42281 27.74778, 85.42265 27.74765...
# 3842  POLYGON ((85.40998 27.71681, 85.40999 27.71605...
# 3843  POLYGON ((85.38598 27.71640, 85.38598 27.71640...
#
# [138 rows x 17 columns]

# %%
total_area = ktm_wards.Shape_Area.sum()
ktm_wards['Area_Proportion'] = ktm_wards.Shape_Area / total_area
ktm_wards.Area_Proportion.sum()
# Out:
# /home/pprasai/pyenvs/base/lib/python3.8/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# 1.0

# %%
def approximate_and_save(dataset, pschema, path):
    _ids = 'province:Bagmati:' + 'district:Kathmandu:' + \
        ktm_wards.Type_GN.str.lower() + ':' + ktm_wards.GaPa_NaPa + \
        ':ward:' + ktm_wards.NEW_WARD_N.astype('str')

    dates = dataset.Date
    props = list(ktm_wards.Area_Proportion)

    for id_idx, _id in enumerate(_ids):
        json_str = {
            "_id": _id,
            "_rev": None,
            "pschema": pschema,
            "data": []
        }

        for idx, date in enumerate(dates):
            json_str['data'].append([
                _id, _id.split(':')[1], _id.split(':')[3],
                _id.split(':')[5],_id.split(':')[-1],
                round(dataset['Kathmandu'][idx] * props[id_idx]).astype('str'),
                None
            ])

        with open(path + _id.split(':')[5] + _id.split(':')[-1] + '.json', 'w') as outfile:
            json.dump(json_str, outfile)

# %%
approximate_and_save(qua_df, "quarantined/v8", "ktm_wardwise_jsons/quarantined/")
approximate_and_save(arr_df, "arrivals/v8", "ktm_wardwise_jsons/arrivals/")
approximate_and_save(iso_df, "isolated/v8", "ktm_wardwise_jsons/isolated/")
approximate_and_save(inf_df, "infected/v8", "ktm_wardwise_jsons/infected/")
approximate_and_save(rec_df, "recovered/v8", "ktm_wardwise_jsons/recovered/")
approximate_and_save(dea_df, "dead/v8", "ktm_wardwise_jsons/dead/")
